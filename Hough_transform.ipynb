# %% [markdown]
# <a href="https://colab.research.google.com/github/IshaqKHATTAK/Computer-Vision/blob/main/Hough_transform.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
img = cv2.imread('123.jpg', cv2.IMREAD_COLOR) 
img=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
plt.imshow(gray)

# %%
edges = cv2.Canny(gray, 50, 50)

# %%
plt.imshow(edges)

# %%
lines = cv2.HoughLinesP(edges, 1, np.pi/180, minLineLength=10, maxLineGap=10,threshold=130)

# %%
for line in lines:
    x1, y1, x2, y2 = line[0]
    cv2.line(img, (x1, y1), (x2, y2), (255, 0, 0), 1)

# %%
plt.imshow(img)
